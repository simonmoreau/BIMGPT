# %%
# https://medium.com/@aminajavaid30/building-a-rag-system-synthesis-67f36efa7c35

# Data Ingestion & Retrieval
import bs4
import re
import os
import getpass
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document
from langchain_community.document_loaders import RecursiveUrlLoader
from langchain_community.document_loaders import GithubFileLoader
from langchain_openai import AzureOpenAIEmbeddings
from langchain_core.vectorstores import InMemoryVectorStore
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from bs4 import BeautifulSoup
from dataclasses import dataclass

# %%
# Initialize the recursive character text splitter
text_splitter = RecursiveCharacterTextSplitter(              
    chunk_size=1000,
    chunk_overlap=200,
    add_start_index=True
)

# %%
if not os.environ.get("AZURE_OPENAI_API_KEY"):
  os.environ["AZURE_OPENAI_API_KEY"] = getpass.getpass("Enter API key for Azure: ")

azureEmbeddings = AzureOpenAIEmbeddings(
    azure_endpoint="https://oai-bim42-test-fr-ai.openai.azure.com",
    azure_deployment="text-embedding-3-small",
    openai_api_version="2025-01-01-preview",
)

# %%
# Load a github repo

if not os.environ.get("GITHUB_PAT"):
  os.environ["GITHUB_PAT"] = getpass.getpass("Enter Github PAT: ")

# %%
@dataclass
class WebViewer:
    name: str
    repos: list[str]
    websites: list[str]

    async def github_repo(self) -> list[Document]:
        github_docs = []
        for repo_name in self.repos:
            loader = GithubFileLoader(
                repo=repo_name, # the repo name
                access_token= os.environ["GITHUB_PAT"],
                github_api_url="https://api.github.com",
                file_filter=lambda file_path: file_path.endswith(
                    ".md"
                ),  # load all markdowns files.
            )   
            async for doc in loader.alazy_load():
                github_docs.append(doc)
        return github_docs

# %%
# Define a solution to parse
viewer = WebViewer(
    name='ThatOpen',
    repos=["ThatOpen/engine_web-ifc", "ThatOpen/engine_components","ThatOpen/engine_ui-components"],
    websites =["ThatOpen/engine_web-ifc", "ThatOpen/engine_components","ThatOpen/engine_ui-components"]
    )

docs = []
all_chunks = []

# Retrive the documents
github_docs = await viewer.github_repo()
print(f"{len(github_docs)} docs in {repo}")
docs = docs + github_docs
# Split the documents into chunks
chunks = text_splitter.split_documents(github_docs)
for chunk in chunks:
    metadata={
        'path':chunk.metadata['path'],
        'sha':chunk.metadata['sha'],
        'source':chunk.metadata['source'],
        'start_index':chunk.metadata['start_index'],
        'chunk_id':chunk.metadata['source'] + str(chunk.metadata['start_index'])}
    new_chunk = Document(page_content= chunk.page_content, metadata = metadata)
    all_chunks.append(new_chunk)
print(f"{len(chunks)} chunks in {repo}")
# Out:
# 11 docs in ThatOpen/engine_ui-components
# 158 chunks in ThatOpen/engine_ui-components

# %%
print(all_chunks[1])
# Out:
# page_content='1.5. "Incompatible With Secondary Licenses"
#     means
#
#     (a) that the initial Contributor has attached the notice described
#         in Exhibit B to the Covered Software; or
#
#     (b) that the Covered Software was made available under the terms of
#         version 1.1 or earlier of the License, but not also under the
#         terms of a Secondary License.
#
# 1.6. "Executable Form"
#     means any form of the work other than Source Code Form.
#
# 1.7. "Larger Work"
#     means a work that combines Covered Software with other material, in
#     a separate file or files, that is not Covered Software.
#
# 1.8. "License"
#     means this document.
#
# 1.9. "Licensable"
#     means having the right to grant, to the maximum extent possible,
#     whether at the time of the initial grant or subsequently, any and
#     all of the rights conveyed by this License.
#
# 1.10. "Modifications"
#     means any of the following:' metadata={'path': 'LICENSE.md', 'sha': 'a612ad9813b006ce81d1ee438dd784da99a54007', 'source': 'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md', 'start_index': 751, 'chunk_id': 'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md751'}

# %%
# Initialize FAISS vector store
index = faiss.IndexFlatL2(len(azureEmbeddings.embed_query("hello world")))

vector_store = FAISS(
    embedding_function=azureEmbeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)

# %%
# Add documents to the vector store

# Create a list of ids
ids = [chunk.metadata['chunk_id'] for chunk in all_chunks]

vector_store.add_documents(documents=all_chunks, ids=ids)
# Out:
# https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md0
# ['https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md0',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md751',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md1591',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md2540',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md3169',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md4033',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md4955',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md5616',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md6224',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md6944',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md7621',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md7971',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md8657',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md9376',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md10273',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md10922',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md11725',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md12237',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md13040',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md13844',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md14689',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md15614',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/LICENSE.md16424',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md0',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md871',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md1440',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md2197',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md3014',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md3877',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md4835',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/benchmark.md0',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/benchmark.md699',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/benchmark.md1544',
#  'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/benchmark.md2320',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/.github/PULL_REQUEST_TEMPLATE.md0',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/.github/PULL_REQUEST_TEMPLATE.md386',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md0',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md124',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md896',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md1669',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md2501',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md3193',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md3907',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md4707',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md5015',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md5030',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md5852',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md6598',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md7273',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md7986',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md8750',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md9537',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md9798',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md10554',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md11316',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md12246',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md12261',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md13059',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md13868',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md14268',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md14379',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md15256',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md15970',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md16817',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md17591',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md18390',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md18405',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md19093',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md19782',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md20564',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md21319',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md22147',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md22947',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md23614',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md23725',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md24547',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md25251',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md25266',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md26052',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md26906',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md27626',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md28276',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md28387',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md29192',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md29995',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md30773',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md31596',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md32464',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md33292',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md34099',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md34954',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md35756',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md36555',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md37423',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md38217',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md38995',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md39010',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md39861',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md40416',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md40677',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md41442',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md42279',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md43050',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md43831',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md44509',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md45464',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md45479',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md46236',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md46991',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md47731',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md48008',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md48119',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md48857',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md49470',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md49883',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md49898',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md50832',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md51622',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md51845',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md52349',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md53299',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/CHANGELOG.md53991',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/LICENSE.md0',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/LICENSE.md434',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/README.md0',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/README.md916',
#  'https://api.github.com/ThatOpen/engine_components/blob/main/README.md1756',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/.github/PULL_REQUEST_TEMPLATE.md0',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/.github/PULL_REQUEST_TEMPLATE.md386',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md0',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md977',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md1751',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md2402',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md3191',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md4185',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md4946',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md5319',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md6114',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md6900',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md7245',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md7957',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md8743',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md9515',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md10413',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/CHANGELOG.md10924',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/LICENSE.md0',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/LICENSE.md434',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md0',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md976',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md1470',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md2360',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md3254',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md4098',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md4985',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md5121',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md5949',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md6789',
#  'https://api.github.com/ThatOpen/engine_ui-components/blob/main/README.md7096']

# %%
results = vector_store.similarity_search(
    "web-ifc is available here",
    k=2,
    filter={"path": "README.md"}
)
for res in results:
    print(f"* {res.page_content} [{res.metadata}]")
# Out:
# * <p align="center">
#   <a href="https://thatopen.com/">TOC</a>
#   |
#   <a href="https://thatopen.github.io/engine_web-ifc/docs">web-ifc documentation</a>
#   |
#   <a href="https://docs.thatopen.com/intro"> platform documentation</a>
#   |
#   <a href="https://thatopen.github.io/engine_web-ifc/demo">demo</a>
#   |
#   <a href="https://people.thatopen.com/">community</a>
#   |
#   <a href="https://www.npmjs.com/package/web-ifc">npm package</a>
# </p>
#
# ![cover](banner.png)
#
# <h1>Web IFC <img src="https://thatopen.github.io/engine_components/resources/favicon.ico" width="32"/></h1>
#
# [![NPM Package][npm]][npm-url]
# [![NPM Package][npm-downloads]][npm-url]
#
# **web-ifc** is a javascript library to read and write ifc files, at native speeds. **web-ifc** is part of the [That Open Company](https://thatopen.com) project, which aims to lower the threshold for developing open BIM applications.
#
# ## Install
#
# `npm install web-ifc`
#
# ## Quick setup
#
# ```JavaScript
# const WebIFC = require("web-ifc/web-ifc-api.js"); [{'path': 'README.md', 'sha': '601070f717d308bdd65f18499c40fe6a847cfd40', 'source': 'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md', 'start_index': 0, 'chunk_id': 'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md0'}]
# * ## Install
#
# `npm install web-ifc`
#
# ## Quick setup
#
# ```JavaScript
# const WebIFC = require("web-ifc/web-ifc-api.js");
#
# // initialize the API
# const ifcApi = new WebIFC.IfcAPI();
#
# // initialize the library
# await ifcApi.Init();
#
# // open a model from data
# let modelID = ifcApi.OpenModel(/* IFC data as a string or UInt8Array */, /* optional settings object */, );
#
# // the model is now loaded! use modelID to fetch geometry or properties
# // checkout examples/usage for some details on how to read/write IFC
#
# // close the model, all memory is freed
# ifcApi.CloseModel(modelID);
#
# ```
#
# See [examples](https://github.com/ThatOpen/engine_web-ifc/tree/main/examples/usage) for more details on how to use web-ifc.
#
# ## Current Build [{'path': 'README.md', 'sha': '601070f717d308bdd65f18499c40fe6a847cfd40', 'source': 'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md', 'start_index': 871, 'chunk_id': 'https://api.github.com/ThatOpen/engine_web-ifc/blob/main/README.md871'}]
